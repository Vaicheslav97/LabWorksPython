# %%
import pytesseract 
from PIL import Image, ImageEnhance, ImageFilter 
   
#im = Image.open("znumbers/34.png") 
#im = Image.open("znumbers/67.tif") 
im = Image.open("znumbers/код.png") 
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=443x253 at 0x4DCEB20>

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
text = pytesseract.image_to_string(im, config='--psm 8')
print(text)
# Out:
# a
