# ...        ...       ...        ...
# 405154   False  0.023423  22.400000
# 405155   False  0.023417  22.400000
# 405156   False  0.019021  26.600000
# 405157   False  0.023400  22.400000
# 405158   False  0.019001  26.700001
# 405159   False  0.016437  19.200001
# 405160   False  0.023301  22.300000
# 405161   False  0.019021  26.600000
# 405162   False  0.016437  19.200001
# 405163   False  0.023394  22.300000
# 405164   False  0.023359  22.300000
# 405165   False  0.019021  26.600000
# 405166   False  0.016552  19.200001
# 405167   False  0.023336  22.300000
# 405168   False  0.023301  22.300000
# 405169   False  0.016437  19.200001
# 405170   False  0.023342  22.200000
# 405171   False  0.019049  26.600000
# 405172   False  0.016437  19.200001
# 405173   False  0.023359  22.300000
# 405174   False  0.019049  26.600000
# 405175   False  0.016437  19.200001
# 405176   False  0.023382  22.300000
# 405177   False  0.023284  22.300000
# 405178   False  0.019117  26.600000
# 405179   False  0.016437  19.200001
# 405180   False  0.023301  22.200000
# 405181   False  0.019076  26.600000
# 405182   False  0.016437  19.200001
# 405183   False  0.023400  22.200000
#
# [405184 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405184 entries, 0 to 405183
# Data columns (total 9 columns):
# ts          405184 non-null float64
# device      405184 non-null object
# co          405184 non-null float64
# humidity    405184 non-null float64
# light       405184 non-null bool
# lpg         405184 non-null float64
# motion      405184 non-null bool
# smoke       405184 non-null float64
# temp        405184 non-null float64
# dtypes: bool(2), float64(6), object(1)
# memory usage: 22.4+ MB

# %%
df.plot()

# %%
#df[df['device']=='b8:27:eb:bf:9d:51']
import time

# %%
#%m-%d %H:%M:%S
#dfk = df[df['device']=='b8:27:eb:bf:9d:51'][['ts','humidity','temp']]
dfk = df[df['device']!=''][['humidity','temp','co','lpg','smoke']]
#dfk = df[df['device']!=''][['humidity','temp']]
#dfk.head()

#dfk['monf']=df['ts'].apply(lambda x: int(time.strftime('%m',time.localtime(x))))
dfk['day']=df['ts'].apply(lambda x: int(time.strftime('%d',time.localtime(x))))
#dfk['Hour']=df['ts'].apply(lambda x: int(time.strftime('%H',time.localtime(x))))
#dfk['Mins']=df['ts'].apply(lambda x: int(time.strftime('%M',time.localtime(x))))
#dfk['Sec']=df['ts'].apply(lambda x: int(time.strftime('%S',time.localtime(x))))
#dfk['dtis']=df['ts'].apply(lambda x: int(int(x)-time.mktime(time.strptime(str(time.strftime('%y-%m-%d',time.localtime(x))), '%y-%m-%d'))))
dfk['dtis']=df['ts'].apply(lambda x: int(int(x)-time.mktime(time.strptime(str(time.strftime('%y-%m-%d',time.localtime(x))), '%y-%m-%d')))/1000)
dfk['light']=df['light'].apply(lambda x: 1 if x==True else 0)
dfk['motion']=df['motion'].apply(lambda x: 1 if x==True else 0)
dfk['co']=df['co'].apply(lambda x: x*1000)
dfk['lpg']=df['lpg'].apply(lambda x: x*1000)
dfk['smoke']=df['smoke'].apply(lambda x: x*1000)
dfk.head()
# Out:
#     humidity       temp        co       lpg      smoke  day    dtis  light  \
# 0  51.000000  22.700000  4.955939  7.650822  20.411270   12  10.894      0
# 1  76.000000  19.700001  2.840089  5.114383  13.274837   12  10.894      0
# 2  50.900000  22.600000  4.976012  7.673227  20.475126   12  10.898      0
# 3  76.800003  27.000000  4.403027  7.023337  18.628225   12  10.899      1
# 4  50.900000  22.600000  4.967364  7.663577  20.447621   12  10.901      0
#
#    motion
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
dfk.plot()

# %%
dfk.dropna()#Неимеет смысла при полных данных
# Out:
#          humidity       temp        co       lpg      smoke  day    dtis  \
# 0       51.000000  22.700000  4.955939  7.650822  20.411270   12  10.894
# 1       76.000000  19.700001  2.840089  5.114383  13.274837   12  10.894
# 2       50.900000  22.600000  4.976012  7.673227  20.475126   12  10.898
# 3       76.800003  27.000000  4.403027  7.023337  18.628225   12  10.899
# 4       50.900000  22.600000  4.967364  7.663577  20.447621   12  10.901
# ...           ...        ...       ...       ...        ...  ...     ...
# 405179  75.300003  19.200001  3.744628  6.246796  16.436744   20  11.013
# 405180  48.500000  22.200000  5.882262  8.660496  23.301035   20  11.013
# 405181  75.699997  26.600000  4.540462  7.181249  19.075959   20  11.016
# 405182  75.300003  19.200001  3.744628  6.246796  16.436744   20  11.016
# 405183  48.400000  22.200000  5.914482  8.694786  23.399597   20  11.017
#
#         light  motion
# 0           0       0
# 1           0       0
# 2           0       0
# 3           1       0
# 4           0       0
# ...       ...     ...
# 405179      0       0
# 405180      0       0
# 405181      1       0
# 405182      0       0
# 405183      0       0
#
# [405184 rows x 9 columns]

# %%
dfk.plot()

# %%
dfk.interpolate().plot()

# %%
#dfk = dfk.fillna(dfk['temp'].median())
#dfk.plot()

# %%
#dfk['date']=df['ts'].apply(lambda x: str(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(x))))
dfk.head()
# Out:
#     humidity       temp        co       lpg      smoke  day    dtis  light  \
# 0  51.000000  22.700000  4.955939  7.650822  20.411270   12  10.894      0
# 1  76.000000  19.700001  2.840089  5.114383  13.274837   12  10.894      0
# 2  50.900000  22.600000  4.976012  7.673227  20.475126   12  10.898      0
# 3  76.800003  27.000000  4.403027  7.023337  18.628225   12  10.899      1
# 4  50.900000  22.600000  4.967364  7.663577  20.447621   12  10.901      0
#
#    motion
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
rdf = dfk.groupby('dtis')['temp'].median()
rdf.plot()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = rdf.index
y = rdf.values


a1 = np.polyfit(x, y, 1)
f1 = np.poly1d(a1)
f1(2050)
rdf.plot()
plt.plot(x,f1(x))

# %%
a2 = np.polyfit(x, y, 2)
f2 = np.poly1d(a2)
rdf.plot()
plt.plot(x,f2(x))

# %%
a3 = np.polyfit(x, y, 3)
f3 = np.poly1d(a3)
rdf.plot()
plt.plot(x, f3(x))

# %%
a50 = np.polyfit(x, y, 50)
f50 = np.poly1d(a50)
rdf.plot()
plt.plot(x,f50(x))
# Out:
# G:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import seaborn as sns

# %%
sns.heatmap(dfk.corr(), annot=True)

# %%
#sns.pairplot(dfk)

# %%
dfk.hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000016CF66D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004D4C7340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004D6F3790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000004D71EBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004D74C0D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004D785400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000004D7854F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004D9C29A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004DA281F0>]],
#       dtype=object)

# %%
# %config InlineBackend.figure_format = 'png'

# %%
sns.pairplot(dfk)

# %%
#%config InlineBackend.figure_format = 'svg'

# %%
sns.lmplot('dtis','temp',data =dfk, hue='light', fit_reg=False);
#plt.scatter(dfk['dtis'],dfk['temp'])

# %%
#dfk.head()
#dfk

#dfkt=dfk[dfk['dtis']>42000]#86400
#dfkt=dfk[dfk['motion']==0]#86400
#dfkt

# %%
sns.boxplot(x='temp', data = dfk)#humidity temp co

# %%
sns.distplot(dfk['temp'])
