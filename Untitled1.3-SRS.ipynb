# %%
import pandas as pd
df = pd.read_csv("C:/Users/User/PytonFolder/glass.csv")

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.plot()

# %%
#df[df['device']=='b8:27:eb:bf:9d:51']
import time

# %%
dfk = df

# %%
dfk.plot()

# %%
dfk.dropna()#Неимеет смысла при полных данных
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
dfk.plot()

# %%
dfk.interpolate().plot()

# %%
#dfk = dfk.fillna(dfk['temp'].median())
#dfk.plot()

# %%
#dfk['date']=df['ts'].apply(lambda x: str(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(x))))
dfk.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
rdf = dfk.groupby('Type')['RI'].median()
rdf.plot()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = rdf.index
y = rdf.values


a1 = np.polyfit(x, y, 1)
f1 = np.poly1d(a1)
f1(2050)
rdf.plot()
plt.plot(x,f1(x))

# %%
a2 = np.polyfit(x, y, 2)
f2 = np.poly1d(a2)
rdf.plot()
plt.plot(x,f2(x))

# %%
a3 = np.polyfit(x, y, 3)
f3 = np.poly1d(a3)
rdf.plot()
plt.plot(x, f3(x))

# %%
a50 = np.polyfit(x, y, 50)
f50 = np.poly1d(a50)
rdf.plot()
plt.plot(x,f50(x))
# Out:
# G:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import seaborn as sns

# %%
sns.heatmap(dfk.corr(), annot=True)

# %%
dfk1 = dfk[dfk['Type'] != ''][['Na','Mg','Al','Ba','Type']]
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
sns.heatmap(dfk1.corr(), annot=True)

# %%
#sns.pairplot(dfk)

# %%
dfk.hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DB6D100>,
# ...
#       dtype=object)

# %%
#dfkid = dfk[dfk['Type'] !=''][['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']]
#dfkmd = dfk['Type']

# %%
# %config InlineBackend.figure_format = 'png'

# %%
sns.pairplot(dfk1, hue='Type')
# Out:
# G:\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# G:\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# G:\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# G:\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# G:\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#%config InlineBackend.figure_format = 'svg'

# %%
dfkid = dfk[dfk['Type'] !=''][['Na','Mg','Al','Ba']]
dfkmd = dfk['Type']
#dfkid
#dfkmd
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
import re
from sklearn import model_selection 
Data_train, Data_test, Marks_train, Marks_test = model_selection.train_test_split(dfkid, dfkmd, test_size = 0.3)

# %%
#Data_train
#Marks_train
#Data_test
#Marks_test

# %%
from scipy import polyval, stats
fit_output = stats.linregress ( dfk1[['Al','Ba']])
slope, intercept, r_value, p_value, slope_std_error = fit_output
print(slope, intercept, r_value, p_value, slope_std_error)
# Out:
# 0.47743510072091216 -0.5148023714668845 0.4794039017045743 1.0697833657185958e-13 0.0600259005637533

# %%
pyplot.plot(dfk1[['Al']],dfk1[['Ba']],'o', label='Data')
pyplot.plot(dfk1[['Al']],intercept+slope*dfk1[['Al']],'r', linewidth=3, label='Linear regresion line')
pyplot.ylabel('Ba')
pyplot.xlabel('Al')
pyplot.show()

# %%
from sklearn import metrics
from sklearn import linear_model
model = linear_model.SGDClassifier(alpha=0.001, max_iter=100, random_state =0)
model.fit(Data_train, Marks_train)
model_predictions = model.predict(Data_test)
print (metrics.accuracy_score(Marks_test, model_predictions))
print (metrics.classification_report(Marks_test, model_predictions))
# Out:
# 0.16923076923076924
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        29
#            3       0.06      1.00      0.12         3
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         2
#            7       0.44      0.89      0.59         9
#
#     accuracy                           0.17        65
#    macro avg       0.08      0.31      0.12        65
# weighted avg       0.06      0.17      0.09        65
# G:\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import cross_val_score
Data_train1, Data_test1, Marks_train1, Marks_test1 = model_selection.train_test_split(dfkid, dfkmd, test_size = 0.3)
model = linear_model.SGDClassifier(alpha=0.001, max_iter=100, random_state =0)
scores = cross_val_score(model, Data_train1,Marks_train1, cv=10 )
print (scores.mean())
# Out:
# 0.3433333333333333
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import StratifiedShuffleSplit
Data_train2, Data_test2, Marks_train2, Marks_test2 = model_selection.train_test_split(dfkid, dfkmd, test_size = 0.3)

r=[]
for i in np.arange(5,100):
    r.append(i)

a=[]
for i in np.linspace(0.0001, 0.001, num =10):
    a.append(i)    
    
param ={
    'alpha' : [0.0001,0.0002,0.0003, 0.0004,0.0005, 0.0006, 0.0007,0.0008, 0.0009, 0.001],
    'n_iter': np.arange(5,100),
}

parameters_grid=ParameterGrid(param)

classifier = linear_model.SGDClassifier(random_state =0)
cv = StratifiedShuffleSplit(Marks_train2, n_splits=10, test_size=0.3, random_state =0)
grid_cv=GridSearchCV(classifier,  param_grid=parameters_grid, scoring ='accuracy', cv=cv)
grid_cv.fit(Data_train2,Marks_train2)
print(grid_cv.best_estimator_)
##cross_val_score(model, Data_train2,Marks_train2, cv=4 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-eb56b4e9cfbc> in <module>
#      21 classifier = linear_model.SGDClassifier(random_state =0)
#      22 cv = StratifiedShuffleSplit(Marks_train2, n_splits=10, test_size=0.3, random_state =0)
# ---> 23 grid_cv=GridSearchCV(classifier,  param_grid=parameters_grid, scoring ='accuracy', cv=cv)
#      24 grid_cv.fit(Data_train2,Marks_train2)
#      25 print(grid_cv.best_estimator_)
#
# G:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ...

# %%
#r = np.arange(5,100)
#npa = np.array([5,100])
#type(r)
#type(npa)
r=[]
for i in np.arange(5,100):
    r.append(i)
type(r)
# Out:
# [0.0001,
#  0.00019999999999999998,
#  0.0003,
#  0.00039999999999999996,
#  0.0005,
#  0.0006000000000000001,
#  0.0007,
#  0.0007999999999999999,
#  0.0009,
#  0.001]

# %%
Data_train1, Data_test1, Marks_train1, Marks_test1 = model_selection.train_test_split(dfkid, dfkmd, test_size = 0.3)
model = linear_model.SGDClassifier(alpha=0.0009, max_iter=96, random_state =0)
scores = cross_val_score(model, Data_train1,Marks_train1, cv=10 )
print (scores.mean())
# Out:
# 0.39619047619047615
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"

# %%
dfkid1 = dfk[dfk['Type'] !=''][['Mg','Al']]
Data_train1, Data_test1, Marks_train1, Marks_test1 = model_selection.train_test_split(dfkid1, dfkmd, test_size = 0.3)
model = linear_model.SGDClassifier(alpha=0.0009, max_iter=96, random_state =0)
scores = cross_val_score(model, Data_train1,Marks_train1, cv=10 )
print (scores.mean())
# Out:
# 0.3952380952380952
# G:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"

# %%
dfkid1 = dfk[dfk['Type'] !=''][['Mg','Al']]
dfkid1['MXA']=dfkid1['Mg']*dfkid1['Al']
dfkid1
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#        Mg    Al     MXA
# 0    4.49  1.10  4.9390
# 1    3.60  1.36  4.8960
# 2    3.55  1.54  5.4670
# 3    3.69  1.29  4.7601
# 4    3.62  1.24  4.4888
# ..    ...   ...     ...
# 209  0.00  2.88  0.0000
# 210  0.00  1.99  0.0000
# 211  0.00  2.02  0.0000
# 212  0.00  1.94  0.0000
# 213  0.00  2.08  0.0000
#
# [214 rows x 3 columns]

# %%
Data_train1, Data_test1, Marks_train1, Marks_test1 = model_selection.train_test_split(dfkid1, dfkmd, test_size = 0.3)
model = linear_model.SGDClassifier(alpha=0.0009, max_iter=96, random_state =0)
scores = cross_val_score(model, Data_train1,Marks_train1, cv=10 )
print (scores.mean())
# Out:
# 0.5171428571428571
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"

# %%
from sklearn.cluster import KMeans
Data_train1, Data_test1, Marks_train1, Marks_test1 = model_selection.train_test_split(dfkid, dfkmd, test_size = 0.3)
model =KMeans(n_clusters=6)
model.fit(Data_train1)
model_pred=model.predict(Data_test1)
print (metrics.accuracy_score(Marks_test1, model_predictions))
print (metrics.classification_report(Marks_test1, model_predictions))
# Out:
# 0.09230769230769231
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00        20
#            3       0.06      0.75      0.12         4
#            5       0.00      0.00      0.00         4
#            6       0.00      0.00      0.00         4
#            7       0.17      0.23      0.19        13
#
#     accuracy                           0.09        65
#    macro avg       0.04      0.16      0.05        65
# weighted avg       0.04      0.09      0.05        65
# G:\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
tree.fit(Data_train,Marks_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
#pip install pydotplus
import pydotplus
from sklearn.tree import export_graphviz
def tree_graph_to_png(tr, feature_names,png_FTS):
    tree_str =export_graphviz(tr, feature_names=feature_names,filled=True, out_file=None)
    graph = pydotplus.graph_from_dot_data(tree_str)
    graph.write_png(png_FTS)

# %%
import os     
os.environ["PATH"] += os.pathsep + 'G:\\Anaconda3\\Library\\bin\\graphviz'

# %%
tree_graph_to_png(tr=tree,feature_names =['Na','Mg','Al','Ba'],png_FTS="../decitionTree2.png")
